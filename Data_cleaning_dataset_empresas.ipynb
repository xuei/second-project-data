# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel ("C:\\Users\\TG\\Desktop\\Ironhack_course\\IronHack_projects\\Project-Week-2-Lisbon\\Dataset_empresas.xls").reset_index()

# %%
df.columns = ["Region","Industry Type", "Nº Companies", "Total Salaries €", "Net Result", "Nº Employees", "Total Turnover €", "Operational Profitability %", "Survival rate %"]


df
# Out:
#                Region                                      Industry Type  \
# 0          Alto Minho  Agricultura, produção animal, caça, floresta e...
# 1          Alto Minho                              Indústrias extrativas
# 2          Alto Minho                         Indústrias transformadoras
# 3          Alto Minho  Eletricidade, gás, vapor, água quente e fria e...
# 4          Alto Minho  Captação, tratamento e distribuição de água; s...
# 5          Alto Minho                                         Construção
# 6          Alto Minho  Comércio por grosso e a retalho; reparação de ...
# 7          Alto Minho                          Transportes e armazenagem
# 8          Alto Minho                Alojamento, restauração e similares
# 9          Alto Minho          Atividades de informação e de comunicação
# 10         Alto Minho                            Atividades imobiliárias
# 11         Alto Minho  Atividades de consultoria, científicas, técnic...
# ...

# %%
df.isnull().sum()
# Out:
# Industry Type                   0
# Nº Companies                    0
# Total Salaries €               44
# Net Result                     44
# Nº Employees                   44
# Total Turnover €               44
# Operational Profitability %    44
# Survival rate %                 0
# dtype: int64

# %%
df.dropna()
# Out:
#                                                       Industry Type  \
# Alto Minho        Agricultura, produção animal, caça, floresta e...
# Alto Minho                               Indústrias transformadoras
# Alto Minho        Eletricidade, gás, vapor, água quente e fria e...
# Alto Minho                                               Construção
# Alto Minho        Comércio por grosso e a retalho; reparação de ...
# Alto Minho                                Transportes e armazenagem
# Alto Minho                      Alojamento, restauração e similares
# Alto Minho                Atividades de informação e de comunicação
# Alto Minho                                  Atividades imobiliárias
# Alto Minho        Atividades de consultoria, científicas, técnic...
# Alto Minho        Atividades administrativas e dos serviços de a...
# Alto Minho                                                 Educação
# Alto Minho                Atividades de saúde humana e apoio social
# ...
