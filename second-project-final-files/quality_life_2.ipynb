# %%
import pandas as pd
import numpy as np

# %%
life = pd.read_excel ("Life.xls")

life['Crimes/Population']= -life['Registered Crimes']/ life['Population']

label= np.arange(3)+1

life['Purchasing power']= [int(value) for value in pd.qcut(life['Purchasing power'],3, labels= label).values ]

life['Environment Expenses']= [int(value) for value in pd.qcut(life['Environment Expenses'],3, labels= label).values ]
life['Gross Income']= [int(value) for value in pd.qcut(life['Gross Income'],3, labels= label).values ]
life['Crimes/Population']= [int(value) for value in pd.qcut(life['Crimes/Population'],3, labels= label).values ]

life['Quality of Life']= life['Purchasing power'] + life['Environment Expenses'] + life['Gross Income'] + life['Crimes/Population']


def quality(i):
    
    if i >=9:
        ft= 'Good Quality of Life'
        return ft
    elif i >=7:
        sc= 'Moderate Quality of Life' 
        return sc  
    else: 
        td ='Low Quality of Life'
        return td

life['Quality of Life']= life['Quality of Life'].apply(quality)

life
# Out:
#                       Unnamed: 0  Purchasing power  Registered Crimes  \
# 0                     Alto Minho                 2               6612
# 1                         Cávado                 3               9605
# 2                            Ave                 3               8807
# 3    Área Metropolitana do Porto                 2              57000
# 4                    Alto Tâmega                 1               2409
# 5                 Tâmega e Sousa                 3               9090
# 6                          Douro                 2               4295
# 7       Terras de Trás-os-Montes                 1               3188
# 8                          Oeste                 3               9681
# 9               Região de Aveiro                 3              10069
# 10             Região de Coimbra                 3              10260
# 11              Região de Leiria                 2               7152
# 12              Viseu Dão Lafões                 1               5830
# 13                   Beira Baixa                 1               2165
# 14                    Médio Tejo                 2               5874
# 15     Beiras e Serra da Estrela                 2               5580
# 16  Área Metropolitana de Lisboa                 3             107734
# 17              Alentejo Litoral                 1               3017
# 18                Baixo Alentejo                 1               3383
# 19               Lezíria do Tejo                 2               7104
# 20                 Alto Alentejo                 1               2967
# 21              Alentejo Central                 1               3767
# 22                       Algarve                 3              20948
#
#     Population  Environment Expenses  Gross Income  Crimes/Population  \
# 0       230954                     1             1                  1
# 1       403891                     1             2                  3
# 2       412669                     1             1                  3
# 3      1722374                     1             3                  1
# 4        86466                     1             1                  2
# 5       417268                     1             1                  3
# 6       191101                     2             1                  3
# 7       107860                     3             1                  1
# 8       356785                     1             2                  2
# 9       362100                     2             3                  2
# 10      434015                     2             3                  3
# 11      284492                     2             3                  3
# 12      252220                     3             2                  3
# 13       80782                     1             3                  2
# 14      232849                     2             2                  2
# 15      213326                     2             1                  2
# 16     2846332                     3             3                  1
# 17       93259                     3             2                  1
# 18      116557                     3             3                  1
# 19      237318                     3             2                  1
# 20      105479                     3             1                  2
# 21      152865                     2             3                  3
# 22      438864                     3             2                  1
#
#              Quality of Life
# 0        Low Quality of Life
# 1       Good Quality of Life
# 2   Moderate Quality of Life
# 3   Moderate Quality of Life
# 4        Low Quality of Life
# 5   Moderate Quality of Life
# 6   Moderate Quality of Life
# 7        Low Quality of Life
# 8   Moderate Quality of Life
# 9       Good Quality of Life
# 10      Good Quality of Life
# 11      Good Quality of Life
# 12      Good Quality of Life
# 13  Moderate Quality of Life
# 14  Moderate Quality of Life
# 15  Moderate Quality of Life
# 16      Good Quality of Life
# 17  Moderate Quality of Life
# 18  Moderate Quality of Life
# 19  Moderate Quality of Life
# 20  Moderate Quality of Life
# 21      Good Quality of Life
# 22      Good Quality of Life
