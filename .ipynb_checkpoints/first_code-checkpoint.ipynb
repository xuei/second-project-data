# %%
import numpy as np
import pandas as pd

data_qualidade = pd.read_excel('Base de Dados - Qualidade de Vida.xls')
data_empresas = pd.read_excel('Dataset_empresas.xls')

# %%
data_empresas.head()
# Out:
#    Unnamed: 0  \
# 0  Alto Minho
# 1  Alto Minho
# 2  Alto Minho
# 3  Alto Minho
# 4  Alto Minho
#
#   CAE Rev. 3 (total, secções A a J, L a N e P a S) - variante 27 (2)  \
# 0  Agricultura, produção animal, caça, floresta e...
# 1                              Indústrias extrativas
# 2                         Indústrias transformadoras
# 3  Eletricidade, gás, vapor, água quente e fria e...
# 4  Captação, tratamento e distribuição de água; s...
#
#    Empresas (N.º) por Localização geográfica (NUTS - 2013) e Atividade económica (Subclasse - CAE Rev. 3); Anual (3)   \
# 0                                               5482
# 1                                                 49
# 2                                               1751
# 3                                                 94
# 4                                                 35
#
#    Remunerações (€) das Empresas por Localização geográfica (NUTS - 2013) e Atividade económica (Subclasse - CAE Rev. 3); Anual (3)   \
# ...

# %%
data_qualidade.head()
# Out:
#   Localização geográfica (NUTS - 2013) (1)  \
# 0                               Alto Minho
# 1                                   Cávado
# 2                                      Ave
# 3              Área Metropolitana do Porto
# 4                              Alto Tâmega
#
#    Proporção de poder de compra (% - no total do País) por Localização geográfica (NUTS - 2013); Bienal  \
# 0                                            0.01797
# 1                                            0.03528
# 2                                            0.03413
# 3                                            0.01745
# 4                                            0.00589
#
#    Crimes registados (N.º) pelas autoridades policiais por Localização geográfica (NUTS - 2013) e Categoria de crime; Anual (3)  \
# 0                                               6612
# 1                                               9605
# 2                                               8807
# ...
